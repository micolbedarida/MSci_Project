# %%
"""
Script extracting wavenumbers, temperature, hot/cold status from temperature '.log' and raw spectra '.txt' files
"""
import matplotlib.pyplot as plt
import numpy as np
import os
import datetime
import math as m
import pandas as pd
import glob
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import itertools
from scipy import interpolate
import matplotlib.cm as cm
import csv

# %%
# VARIABLES

file_name = 'IC_raw_spectra_(2019_02_25_'

#path_raw = 'H:/MSci Project/sand_outside' #path containing all raw spectra RACHEL
path_raw = '/Users/micol/Documents/Imperial/Year4/Master_Project/sand_outside' #path containing all raw spectra

file_path_tau = path_raw + "/Laura_simulations"
#path_sensitivity = 'H:/MSci Project/Sensitivity_Analysis'
path_sensitivity = '/Users/micol/Documents/Imperial/Year4/Master_Project/sand_outside/Sensitivity_Analysis_400'

# %%
#FUNCTIONS

def read_file(directory, filename, separator, rowstoskip, head='infer'):
    """
    Reads an external file and outputs it as a Pandas Dataframe
    Input: Directory, Filename (Strings)
    Output: Pandas Dataframe
    """
    path=os.path.join(directory, filename)
    dataset = pd.read_csv(path, header = head, sep=separator, skiprows=rowstoskip)
    
    return dataset


def planck(wavenumber, temperature): # T in Kelvin, wavenumber in cm^-1
    """
    Calculates spectral radiance of a black body at some wavenumber and temperature
    Input: wavenumber (units: cm^{-1}), and temperature T (units: Kelvin) - (Integers or Floats)
    Output: spectral radiance (units: W m^{-2} sr^{-1} cm^{-1}) - (Float)
    """
    h = 6.626e-34
    c = 3.0e+8
    k = 1.381e-23

    planck_a = 2*h*(c**2)
    planck_e = h*c/k
    radiance = 100*planck_a*((wavenumber*100)**3)/(np.exp(planck_e*(wavenumber*100)/temperature)-1)

    return radiance


def read_raw_spectra(directory, filename):
    """
    Reads spectrum file and calculates the average of the 4 spectra
    Input: Directory, Filename (Strings)
    Output: average_spectrum (NumPy Array)
    """
    file_data = read_file(path_raw, filename, separator='  ', rowstoskip=5, head=None)
    spectrum1 = file_data[1].values
    spectrum2 = file_data[2].values
    spectrum3 = file_data[3].values
    spectrum4 = file_data[4].values
    
    return spectrum1,spectrum2,spectrum3,spectrum4

# %%
def inv_resp_function(hbb_spectrum, cbb_spectrum):
    
    V_diff = np.array(hbb_spectrum)-np.array(cbb_spectrum)
    
    temp_average_h = times_temps.at[hbb_index,'HBB_temp']
    temp_average_c = times_temps.at[cbb_index,'CBB_temp']

    radiances_avg_h = [planck(wn, float(temp_average_h)+273.15) for wn in wavenums_cut]
    radiances_avg_c = [planck(wn, float(temp_average_c)+273.15) for wn in wavenums_cut]
    rad_diff = np.array(radiances_avg_h) - np.array(radiances_avg_c)

    def division(raw_val,planck_val):
        if raw_val == 0:
            div = 0
        else:
            div = raw_val/planck_val
        return div

    division_vec = np.vectorize(division)
    ratio = division_vec(V_diff, rad_diff)

    return(ratio)


def plot_planck(t, wns):
    radiances = []
    for w in wns:
        radiances.append(planck(w, t+273.15))
    return radiances

# %%
nesr = read_file(path_sensitivity, 'NESR.csv', ',', rowstoskip=None, head=None)
nesr_wns = nesr[0]
nesr_rad = nesr[1]/1000*2 #factor 2 because jon's is over 64 coadds, whereas we have 16

plt.figure(figsize=(15,10))
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.ylabel('Radiance W m$^{-2}$ sr$^{-1}$ (cm$^{-1})^{-1}$', fontsize=20)
plt.scatter(nesr_wns, nesr_rad)
plt.show()

f_nesr = interpolate.interp1d(nesr_wns, nesr_rad)

# %%
#create list of file paths starting with file_name from 'path_raw' directory
measurements = len(glob.glob(path_raw + '/'+ file_name + '*')) #filepaths of all 'IC_raw_spectra' files
m_numbers = list(range(measurements)) #list of file name endings (integers)

for i in m_numbers:
    #checks that files have associated temperature measurements, and removes the files if not
    temp_check = read_file(path_raw, file_name + '{0:03}'.format(i) + '.txt', separator=',', rowstoskip=None, head=None).iloc[1,0]
    temp_check_float = float(temp_check.split()[0])
    if temp_check_float == 0.0:
        m_numbers.pop(i)

files = [file_name + '{0:03}'.format(num) + '.txt' for num in m_numbers][:-2] #final list of strings of file names, in order

# %%
columns_ = ['RT0','RT1','RT2','Dummy','RT3','RT4','HBB_temp','CBB_temp','Time', 'Orientation'] #columns for Pandas DataFrame

read_temps = []

for i in np.arange(0,len(files)):
    #Go through files and retrieve temperatures and orientations of spectra
    read_temps.append( read_file(path_raw, files[i], separator=',', rowstoskip=None, head=None).iloc[1:5,0].str.split() )
    read_temps_flat = list(itertools.chain(*read_temps)) #flatten read_temps_i

times_temps = pd.DataFrame(read_temps_flat, columns = columns_)

# %%
wavenums = read_file(path_raw, files[0], separator='  ', rowstoskip=5, head=None)[0].values
# Out:
# /Users/micol/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.

# %%
wavenums_cut = [wn for wn in wavenums if wn>400]
wavenums_min_ind = [i for i,x in enumerate(wavenums) if x >400][0]

plt.figure(figsize=(15,10))
all_ems = []

t_file = '2103_3063'
hbb_index = 528
cbb_index = 519
sky_index = 503
surface_index = 525
atm_t = 21.03 #21.03
surf_t = 17.3 #17.3
#time = '15:07'


hbb_spectrum = read_raw_spectra(path_raw, files[int(np.floor(hbb_index/4))])[hbb_index%4][wavenums_min_ind:]
cbb_spectrum = read_raw_spectra(path_raw, files[int(np.floor(cbb_index/4))])[cbb_index%4][wavenums_min_ind:]
response = inv_resp_function(hbb_spectrum, cbb_spectrum)

temp_average_h = times_temps.at[hbb_index,'HBB_temp']
radiances_avg_h = np.array([planck(wn, float(temp_average_h)+273.15) for wn in wavenums_cut])

sky = read_raw_spectra(path_raw, files[int(np.floor(sky_index/4))])[sky_index%4][wavenums_min_ind:]
surf = read_raw_spectra(path_raw, files[int(np.floor(surface_index/4))])[surface_index%4][wavenums_min_ind:]

sky_rad = np.divide((sky-hbb_spectrum), response) + radiances_avg_h
surf_rad = np.divide((surf-hbb_spectrum), response) + radiances_avg_h

tau_wn= []
taus_rtm = []
trans_file = np.loadtxt(file_path_tau + '/' + t_file +'.txt')
for i in np.arange(trans_file.shape[0]):
    tau_wn.append(trans_file[i][0])
    taus_rtm.append(trans_file[i][1])
f_trans = interpolate.interp1d(tau_wn, taus_rtm)


"""pert_down = 1.00 
pert_up = 1.00"""



pert_tau = 1.0

downs_minus = []
downs_plus = []
downs=[]

ups_minus=[]
ups_plus=[]
ups = []

taus = []
wns =[]
for i in range(len(wavenums_cut)):
    if f_trans(wavenums_cut[i]) >0.9:
        taus.append(f_trans(wavenums_cut[i]) * pert_tau)
        wns.append(wavenums_cut[i])
        
        downs.append(sky_rad[i])
        downs_minus.append(sky_rad[i] - f_nesr(wavenums_cut[i]))
        downs_plus.append(sky_rad[i] + f_nesr(wavenums_cut[i]))
        
        ups.append(surf_rad[i])
        ups_minus.append(surf_rad[i] - f_nesr(wavenums_cut[i]))
        ups_plus.append(surf_rad[i] + f_nesr(wavenums_cut[i]))
        
BBatm = plot_planck(atm_t, wns)
BBsurf = plot_planck(surf_t, wns)

N1 = np.array(ups)
N2 = np.array([t**2*d for t, d in zip(taus, downs)])
N3 = np.array([(1-t**2)*b for t, b in zip(taus, BBatm)])

N = N1-N2-N3

D1 = np.array([t*b for t, b in zip(taus, BBsurf)])
D2 = np.array([t**2*d for t, d in zip(taus, downs)])
D3 = np.array([t*(1-t)*b for t, b in zip(taus, BBatm)])

D = D1-D2-D3

emissivity = N/D

"""N1 = np.array(ups)
N2 = np.array([t**2*d for t, d in zip(taus, downs)])
N3 = np.array([(1-t**2)*b for t, b in zip(taus, BBatm)])

N = N1-N2-N3

D1 = np.array([t*b for t, b in zip(taus, BBsurf)])
D2 = np.array([t**2*d for t, d in zip(taus, downs)])
D3 = np.array([t*(1-t)*b for t, b in zip(taus, BBatm)])

D = D1-D2-D3

emissivity = N/D"""


"""with open(os.path.join(path_sensitivity, 'Tau_' + str(pert_tau) +'ND' +'.csv'), "w") as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(wns,emissivity,N1,N2,N3,D1,D2,D3))"""

"""with open(os.path.join(path_sensitivity, 'Surf_T_' + str(surf_t)+'ND' + '.csv'), "w") as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(wns,emissivity,N1,N2,N3,D1,D2,D3))"""

"""with open(os.path.join(path_sensitivity, 'Atm_T_' + str(atm_t) +'ND'+ '.csv'), "w") as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(wns,emissivity,N1,N2,N3,D1,D2,D3))"""

"""with open(os.path.join(path_sensitivity, 'Down_' + str(pert_down) +'ND'+ '.csv'), "w") as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(wns,emissivity,N1,N2,N3,D1,D2,D3))"""
"""
with open(os.path.join(path_sensitivity, 'Up_' + 'plus' +'ND'+ '.csv'), "w") as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(wns,emissivity,N1,N2,N3,D1,D2,D3))"""
# Out:
# /Users/micol/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.
# '\nwith open(os.path.join(path_sensitivity, \'Up_\' + \'plus\' +\'ND\'+ \'.csv\'), "w") as f:\n    writer = csv.writer(f, delimiter=\'\t\')\n    writer.writerows(zip(wns,emissivity,N1,N2,N3,D1,D2,D3))'

# %%
fig=plt.figure(figsize=(12,8))
plt.scatter(wns, N1, s=1)
plt.scatter(wns, N2, s=1)
plt.scatter(wns, N3, s=1)
plt.scatter(wns, N1-N2-N3, s=1)
plt.legend(['N1','N2', 'N3'])
plt.axhline(y=0, c='k', alpha=.5)
plt.show()

# %%
fig=plt.figure(figsize=(12,8))
plt.scatter(wns, D1, s=1)
plt.scatter(wns, D2, s=1)
plt.scatter(wns, D3, s=1)
plt.scatter(wns, D1-D2-D3, s=1)
plt.legend(['D1','D2','D3'])
plt.axhline(y=0, c='k', alpha=.5)
plt.show()

# %%
plt.scatter(wns, N1-N2-N3, s=1)
plt.scatter(wns, D1-D2-D3, s=1)
#plt.scatter(wns,(N1-N2-N3)/(D1-D2-D3))
#plt.ylim((-2,2))
plt.show()

# %%
atm_up_ND = read_file(path_sensitivity+'/ND', 'Atm_T_21.03ND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(atm_up_ND[0], (atm_up_ND[2]-atm_up_ND[3]-atm_up_ND[4]), s=1)
plt.scatter(atm_up_ND[0], (atm_up_ND[5]-atm_up_ND[6]-atm_up_ND[7]), s=1)
plt.show()
plt.scatter(atm_up_ND[0][1000:1200], (atm_up_ND[2][1000:1200]-atm_up_ND[3][1000:1200]-atm_up_ND[4][1000:1200]), s=1)
plt.scatter(atm_up_ND[0][1000:1200], (atm_up_ND[5][1000:1200]-atm_up_ND[6][1000:1200]-atm_up_ND[7][1000:1200]), s=1)
plt.show()

# %%
atm_base_ND = read_file(path_sensitivity+'/ND', 'Atm_T_21.03ND.csv', separator = '\t', rowstoskip=None, head=None)
n=4
plt.scatter(atm_up_ND[0], (atm_up_ND[n]-atm_base_ND[n])/atm_base_ND[n])
plt.show()

# %%
atm_down_ND = read_file(path_sensitivity+'/ND', 'Atm_T_20.23ND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(atm_down_ND[0], (atm_down_ND[2]-atm_down_ND[3]-atm_down_ND[4]), s=1)
plt.scatter(atm_down_ND[0], (atm_down_ND[5]-atm_down_ND[6]-atm_down_ND[7]), s=1)
plt.show()

# %%
atm_base_ND = read_file(path_sensitivity+'/ND', 'Atm_T_21.03ND.csv', separator = '\t', rowstoskip=None, head=None)
n=7
plt.scatter(atm_down_ND[0], (atm_down_ND[n]-atm_base_ND[n])/atm_base_ND[n])
plt.show()

# %%
surf_up_ND = read_file(path_sensitivity+'/ND', 'Surf_T_17.3ND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(surf_up_ND[0], (surf_up_ND[2]-surf_up_ND[3]-surf_up_ND[4]), s=1)
plt.scatter(surf_up_ND[0], (surf_up_ND[5]-surf_up_ND[6]-surf_up_ND[7]), s=1)
plt.show()

# %%
surf_base_ND = read_file(path_sensitivity+'/ND', 'Surf_T_17.3ND.csv', separator = '\t', rowstoskip=None, head=None)
n=5
plt.scatter(surf_up_ND[0], (surf_up_ND[n]-surf_base_ND[n])/surf_base_ND[n])
plt.show()

# %%
surf_down_ND = read_file(path_sensitivity+'/ND', 'Surf_T_16.8ND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(surf_down_ND[0], (surf_down_ND[2]-surf_down_ND[3]-surf_down_ND[4]), s=1)
plt.scatter(surf_down_ND[0], (surf_down_ND[5]-surf_down_ND[6]-surf_down_ND[7]), s=1)
plt.show()

# %%
surf_base_ND = read_file(path_sensitivity+'/ND', 'Surf_T_17.3ND.csv', separator = '\t', rowstoskip=None, head=None)
n=5
plt.scatter(surf_down_ND[0], (surf_down_ND[n]-surf_base_ND[n])/surf_base_ND[n])
plt.show()

# %%
downwelling_up_ND = read_file(path_sensitivity+'/ND', 'Down_plusND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(downwelling_up_ND[0], (downwelling_up_ND[2]-downwelling_up_ND[3]-downwelling_up_ND[4]), s=1)
plt.scatter(downwelling_up_ND[0], (downwelling_up_ND[5]-downwelling_up_ND[6]-downwelling_up_ND[7]), s=1)
plt.show()

# %%
downwelling_base_ND = read_file(path_sensitivity+'/ND', 'Down_baseND.csv', separator = '\t', rowstoskip=None, head=None)
n=3
plt.scatter(downwelling_up_ND[0], (downwelling_up_ND[n]-downwelling_base_ND[n])/downwelling_base_ND[n])
plt.show()

# %%
downwelling_down_ND = read_file(path_sensitivity+'/ND', 'Down_minusND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(downwelling_down_ND[0], (downwelling_down_ND[2]-downwelling_down_ND[3]-downwelling_down_ND[4]), s=1)
plt.scatter(downwelling_down_ND[0], (downwelling_down_ND[5]-downwelling_down_ND[6]-downwelling_down_ND[7]), s=1)
plt.show()

# %%
downwelling_base_ND = read_file(path_sensitivity+'/ND', 'Down_baseND.csv', separator = '\t', rowstoskip=None, head=None)
n=6
plt.scatter(downwelling_down_ND[0], (downwelling_down_ND[n]-downwelling_base_ND[n])/downwelling_base_ND[n])
plt.show()

# %%
upwelling_up_ND = read_file(path_sensitivity+'/ND', 'Up_plusND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(upwelling_up_ND[0], (upwelling_up_ND[2]-upwelling_up_ND[3]-upwelling_up_ND[4]), s=1)
plt.scatter(upwelling_up_ND[0], (upwelling_up_ND[5]-upwelling_up_ND[6]-upwelling_up_ND[7]), s=1)
plt.legend(['N', 'D'])
plt.show()

# %%
upwelling_base_ND = read_file(path_sensitivity+'/ND', 'Up_baseND.csv', separator = '\t', rowstoskip=None, head=None)
n=2
plt.scatter(upwelling_up_ND[0], (upwelling_up_ND[n]-upwelling_base_ND[n])/upwelling_base_ND[n])
plt.show()

# %%
upwelling_down_ND = read_file(path_sensitivity+'/ND', 'Up_minusND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(upwelling_down_ND[0], (upwelling_down_ND[2]-upwelling_down_ND[3]-upwelling_down_ND[4]), s=1)
plt.scatter(upwelling_down_ND[0], (upwelling_down_ND[5]-upwelling_down_ND[6]-upwelling_down_ND[7]), s=1)
plt.legend(['N', 'D'])
plt.show()

# %%
upwelling_base_ND = read_file(path_sensitivity+'/ND', 'Up_baseND.csv', separator = '\t', rowstoskip=None, head=None)
n=2
plt.scatter(upwelling_down_ND[0], (upwelling_down_ND[n]-upwelling_base_ND[n])/upwelling_base_ND[n])
plt.show()

# %%
tau_down_ND = read_file(path_sensitivity+'/ND', 'Tau_0.98ND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(tau_down_ND[0], (tau_down_ND[2]-tau_down_ND[3]-tau_down_ND[4]), s=1)
plt.scatter(tau_down_ND[0], (tau_down_ND[5]-tau_down_ND[6]-tau_down_ND[7]), s=1)
plt.legend(['N', 'D'])
plt.show()

# %%
plt.scatter(tau_down_ND[0], ((tau_down_ND[2]-tau_down_ND[3]-tau_down_ND[4])-(tau_down_ND[5]-tau_down_ND[6]-tau_down_ND[7]))/ 
            ((tau_down_ND[5]-tau_down_ND[6]-tau_down_ND[7])))
plt.ylim((-10,10))
plt.show()

# %%
tau_base_ND = read_file(path_sensitivity+'/ND', 'Tau_1.0ND.csv', separator = '\t', rowstoskip=None, head=None)
n=7
plt.scatter(tau_down_ND[0], (tau_down_ND[n]-tau_base_ND[n])/tau_base_ND[n])
plt.show()

# %%
tau_up_ND = read_file(path_sensitivity+'/ND', 'Tau_1.02ND.csv', separator = '\t', rowstoskip=None, head=None)
plt.scatter(tau_up_ND[0], (tau_up_ND[2]-tau_up_ND[3]-tau_up_ND[4]), s=1)
plt.scatter(tau_up_ND[0], (tau_up_ND[5]-tau_up_ND[6]-tau_up_ND[7]), s=1)
plt.legend(['N', 'D'])
plt.show()

# %%
plt.scatter(tau_up_ND[0], ((tau_up_ND[2]-tau_up_ND[3]-tau_up_ND[4])-(tau_up_ND[5]-tau_up_ND[6]-tau_up_ND[7]))/ ((tau_up_ND[5]-tau_up_ND[6]-tau_up_ND[7])))
plt.ylim((-10,10))
plt.show()

# %%
tau_base_ND = read_file(path_sensitivity+'/ND', 'Tau_1.0ND.csv', separator = '\t', rowstoskip=None, head=None)
n=7
plt.scatter(tau_up_ND[0], (tau_up_ND[n]-tau_base_ND[n])/tau_base_ND[n])
plt.show()

# %%
fig=plt.figure(figsize=(10,6))

plt.scatter(wns, ups, s=1)
plt.scatter(wns, downs, s=1)
plt.legend(['upwelling', 'downwelling'])
plt.show()

# %%
plt.scatter(wns,taus, s=1.5)
plt.show()

# %%
plt.scatter(wns, BBatm)
plt.scatter(wns, BBsurf)
plt.show()

# %%
perturbs = sorted(glob.glob(path_sensitivity + '/' + 'Surf_T_' + '*'))

perturbed_ts = []
perturbed_lists = []
for file in perturbs:
    file_end = os.path.basename(file)
    perturbed_lists.append(read_file(path_sensitivity, file_end, separator = '\t', rowstoskip=None, head=None))
    perturbed_ts.append(file_end.strip('Surf_T_.csv'))

# %%
colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbed_ts))) # last number is number of colours you want

fig = plt.figure(figsize=(14,12))

for (l,name, color) in zip(perturbed_lists, perturbed_ts, colors):
    plt.scatter(l[0], l[1], s=1.5, label=name, c=color)
    
#plt.title('Perturbed emissivities due to surface temperature variation from 17.3', fontsize=20)
plt.ylabel('Emissivity', fontsize=20)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.tick_params(labelsize=20, labelcolor='black')

legend = plt.legend(fontsize=20, title='Surface temp ($\degree$C)', markerscale=10)
plt.setp(legend.get_title(),fontsize=20)
plt.ylim(0.5,1)
plt.xlim(400,1200)
plt.grid()
fig.savefig('Graphs/Pert_Surf_temp.png', dpi=600)
plt.show()

# %% [markdown]
# plot d emissivity by dts for a certain wavenumeber,.
#
# what we are looking at is unceratinty due to uncertainty in a certain temperature
#
# combine unceratinty total uncertainty in quadrature, and have error bars and break down how much is due to each term. ConlcusionL waht is the quantity that we need to measure better to imporve emissivities.
#
# de;ta t against delta emissivity - could have it as a plot inside a plot
#
# error due to temp measured a couple of centimeters into the water
# best case uncertainty is 0.1 because that is the reading error. WOuld expect as you heat water and develop skin layer, top of water might be a bit warmer than water underneath. Have look in literature for skin temperature water to underneath, just so we can quote it. Ours is more likelty to be too cold. Would make our emissivity go down a bit.
# probably doing better than 0.5 error.
#
# DSay in future design find some way to look at stratification or alternatively mixing the water, maybe similar to Newman.

# %%
# Look at difference between each perturbation and the unperturbed one
delta_surf_t = []

colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbed_lists))) # last number is number of colours you want
fig = plt.figure(figsize=(15,10))

for (l,name, color) in zip(perturbed_lists, perturbed_ts, colors):
    diff = [(a-b) for (a,b) in zip(l[1], perturbed_lists[5][1])]
    delta_surf_t.append(diff)
    plt.scatter(l[0], diff, s=1, label=name, c=color)

plt.title('Difference between perturbed cases and unperturbed case of 17.3', fontsize=20)
plt.ylabel('Difference in emissivity', fontsize=20)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.tick_params(labelsize=16, labelcolor='black')

legend = plt.legend(fontsize=16, title='Surface temp', markerscale=4)
plt.setp(legend.get_title(), fontsize=16)

plt.ylim(-5,5)
plt.xlim([400,1200])
plt.grid()
fig.savefig('Graphs/Pert_Surf_temp_diff.png', dpi=600)
plt.show()

# %%
t_surf_diffs = np.arange(-0.5, 0.6, 0.1)

i = 50

for (a,t) in zip(delta_surf_t, t_surf_diffs):
    plt.scatter(t, a[i])
plt.title(str(l[0][i]))
plt.xlabel('$\Delta$T')
plt.ylabel('$\Delta \epsilon$')

plt.show()

# %%
atm_files = sorted(glob.glob(path_sensitivity + '/' + 'Atm_T_' + '*'))

atm_names = []
perturbs_atm = []
for file in atm_files:
    file_end = os.path.basename(file)
    perturbs_atm.append(read_file(path_sensitivity, file_end, separator = '\t', rowstoskip=None, head=None))
    atm_names.append(file_end.strip('Atm_T_.csv'))

# %%
colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbs_atm))) # last number is number of colours you want

fig = plt.figure(figsize=(14,12))

for (l,name, color) in zip(perturbs_atm, atm_names, colors):
    plt.scatter(l[0], l[1], s=1.5, label=name, c=color)
    
#plt.title('Perturbed emissivities due to atmospheric temperature variation', fontsize=20)
plt.ylabel('Emissivity', fontsize=20)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.tick_params(labelsize=20, labelcolor='black')

legend = plt.legend(fontsize=20, title='Atm temp ($\degree$C)', markerscale=10)
plt.setp(legend.get_title(),fontsize=20)
plt.ylim(0.5,1.)
plt.xlim(400,1200)
plt.grid()
fig.savefig('Graphs/Pert_Atm_temp_1.png', dpi=600)
plt.show()

# %%
# Look at difference between each perturbation and the unperturbed one

colors = cm.gist_rainbow(np.linspace(0, .8, len(atm_files))) # last number is number of colours you want
fig = plt.figure(figsize=(15,10))

delta_atm_t = []

for (l, name, color) in zip(perturbs_atm, atm_names, colors):
    diff = [(a-b) for (a,b) in zip(l[1], perturbs_atm[4][1])]
    delta_atm_t.append(diff)
    plt.scatter(l[0], diff, s=1, label=name, c=color)

plt.title('Difference between perturbed cases and unperturbed case of 21.03', fontsize=20)
plt.ylabel('Difference in emissivity', fontsize=20)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.tick_params(labelsize=16, labelcolor='black')

legend = plt.legend(fontsize=16, title='Atmospheric temp', markerscale=4)
plt.setp(legend.get_title(), fontsize=16)

plt.ylim(-1,1)
plt.grid()
fig.savefig('Graphs/Pert_Atm_temp_diff.png', dpi=600)
plt.show()

# %%
t_atm_diffs = np.arange(-0.8, 0.9, 0.2)

i = 50

for (a,t) in zip(delta_atm_t, t_atm_diffs):
    plt.scatter(t, a[i])
plt.title(str(l[0][i]))
plt.xlabel('$\Delta$T atm')
plt.ylabel('$\Delta \epsilon$')

plt.show()

# %%
down_files = sorted(glob.glob(path_sensitivity + '/' + 'Down_' + '*'))

down_names = []
perturbs_down = []
for file in down_files:
    file_end = os.path.basename(file)
    perturbs_down.append(read_file(path_sensitivity, file_end, separator = '\t', rowstoskip=None, head=None))
    down_names.append(file_end.strip('Down_.csv'))

# %%
colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbs_down))) # last number is number of colours you want

fig = plt.figure(figsize=(15,12))


for (l,name, color) in zip(perturbs_down, down_names, colors):
    plt.scatter(l[0], l[1], s=1.5, label=name, c=color)
    
#plt.title('Perturbed emissivities due to downwelling variation', fontsize=20)
plt.ylabel('Emissivity', fontsize=36)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=36)
plt.tick_params(labelsize=36, labelcolor='black')

legend = plt.legend(fontsize=36, title='Scaling factor', markerscale=10)
plt.setp(legend.get_title(),fontsize=36)
plt.ylim(0.,1.4)
plt.xlim(400,1199)


plt.grid()
fig.savefig('Graphs/Pert_Downwelling.png', dpi=600)


plt.show()

# %% [markdown]
# shows that is more sensiitvie at low awvenumbers. to downwelling where teransmission i slower, Have bigger scale.
#
# Look at noise equivalent spectral radiance from Jon.

# %%
# Look at percentage deviation between each perturbation and the unperturbed one

colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbs_down)))

fig = plt.figure(figsize=(15,10))

delta_down = []


for (l,name, color) in zip(perturbs_down, down_names, colors):
    diff = [(a-b) for (a,b) in zip(l[1], perturbs_down[0][1])]
    delta_down.append(diff)
    plt.scatter(l[0], diff, s=1.5, label=name, c=color)

plt.title('Percent Difference from unperturbed case', fontsize=20)
plt.ylabel('Percent difference in emissivity (%)', fontsize=20)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.tick_params(labelsize=16, labelcolor='black')
legend = plt.legend(fontsize=16, title='Scaling factor', markerscale=4)
plt.setp(legend.get_title(),fontsize=16)

#plt.ylim(0,1)
plt.grid()
fig.savefig('Graphs/Pert_Downwelling_percentage.png', dpi=600)
plt.show()

# %% [markdown]
# See notes from NESR on jons word file
# we may not have taken as many scans as jon - broad indicative idea. If it causes big errrors, can scale it but keep shape the same
#
# downwelling has t squaredd in front so more sensitive to upweeling

# %%
up_files = sorted(glob.glob(path_sensitivity + '/' + 'Up_' + '*'))

up_names = []
perturbs_up = []
for file in up_files:
    file_end = os.path.basename(file)
    perturbs_up.append(read_file(path_sensitivity, file_end, separator = '\t', rowstoskip=None, head=None))
    up_names.append(file_end.strip('Up_.csv'))

# %%
colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbs_up))) # last number is number of colours you want

fig = plt.figure(figsize=(15,12))

for (l,name, color) in zip(perturbs_up, up_names, colors):
    plt.scatter(l[0], l[1], s=1.5, label=name, c=color)
    
#plt.title('Perturbed emissivities due to upwelling variation', fontsize=36)
plt.ylabel('Emissivity', fontsize=36)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=36)
plt.tick_params(labelsize=36, labelcolor='black')

legend = plt.legend(fontsize=36, title='Scaling factor', markerscale=10)
plt.setp(legend.get_title(),fontsize=36)
plt.ylim(0.,1.4)
plt.xlim(400,1199)

plt.grid()
fig.savefig('Graphs/Pert_Upwelling.png', dpi=600)
plt.show()

# %%
colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbs_up)))

fig = plt.figure(figsize=(15,10))

delta_up = []


for (l,name, color) in zip(perturbs_up, up_names, colors):
    diff = [(a-b) for (a,b) in zip(l[1], perturbs_up[0][1])]
    delta_up.append(diff)
    plt.scatter(l[0], diff, s=1, label=name, c=color)

plt.title('Percent Difference from unperturbed case', fontsize=20)
plt.ylabel('Percent difference in emissivity (%)', fontsize=20)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.tick_params(labelsize=16, labelcolor='black')
legend = plt.legend(fontsize=16, title='Scaling factor', markerscale=4)
plt.setp(legend.get_title(),fontsize=16)

#plt.ylim(0,1)
plt.grid()
fig.savefig('Graphs/Pert_Upwelling_percentage.png', dpi=600)
plt.show()

# %%
tau_files = sorted(glob.glob(path_sensitivity + '/' + 'Tau_' + '*'))

tau_names = []
perturbs_tau = []
for file in tau_files:
    file_end = os.path.basename(file)
    perturbs_tau.append(read_file(path_sensitivity, file_end, separator = '\t', rowstoskip=None, head=None))
    tau_names.append(file_end.strip('Tau_.csv'))

# %%
colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbs_tau))) # last number is number of colours you want

fig = plt.figure(figsize=(14,12))

for (l,name, color) in zip(perturbs_tau, tau_names, colors):
    plt.scatter(l[0], l[1], s=1.5, label=name, c=color)
    
#plt.title('Perturbed emissivities due to transmission variation', fontsize=36)
plt.ylabel('Emissivity', fontsize=20)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.tick_params(labelsize=20, labelcolor='black')

legend = plt.legend(fontsize=20, title='Scaling factor', markerscale=10)
plt.setp(legend.get_title(),fontsize=20)
plt.ylim(0.5,1)
plt.xlim(400,1160)

plt.grid()
fig.savefig('Graphs/Pert_trans.png', dpi=600)
plt.show()

# %%
colors = cm.gist_rainbow(np.linspace(0, .8, len(perturbs_tau)))

fig = plt.figure(figsize=(15,10))

delta_tau = []


for (l,name, color) in zip(perturbs_tau, tau_names, colors):
    diff = [(a-b) for (a,b) in zip(l[1], perturbs_tau[2][1])]
    delta_tau.append(diff)
    plt.scatter(l[0], diff, s=1, label=name, c=color)

plt.title('Difference from unperturbed case', fontsize=20)
plt.ylabel('Difference in emissivity (%)', fontsize=20)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=20)
plt.tick_params(labelsize=16, labelcolor='black')
legend = plt.legend(fontsize=16, title='Scaling factor', markerscale=4)
plt.setp(legend.get_title(),fontsize=16)

#plt.ylim(0,1)
plt.grid()
#fig.savefig('Graphs/Pert_Upwelling_percentage.png', dpi=600)
plt.show()

# %% [markdown]
# pick surf delta = 0.5
# pick atm delta = 0.2
# pick tau

# %%
tau1 = np.loadtxt(file_path_tau + '/2239_2799.txt')
tau2 = np.loadtxt(file_path_tau + '/2103_3063.txt')
tau_diff_array = []
tau_perc_array = []
tau_wns_ = []

for (i,j) in zip(tau1, tau2):
    diff = i[1]-j[1]
    perc = diff/i[1] *100
    tau_diff_array.append(diff)
    tau_perc_array.append(perc)
    tau_wns_.append(i[0])
    
plt.figure(figsize=(15,10))
plt.scatter(tau_wns_,tau_perc_array, s=1)
plt.ylim(-10,10)
plt.show()
# Out:
# /Users/micol/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':

# %%
#tau1 = read_file(file_path_tau, '2239_2799.txt', separator, rowstoskip, head='infer'):
tau3 = np.loadtxt(file_path_tau + '/2096_2922.txt')
tau2 = np.loadtxt(file_path_tau + '/2103_3063.txt')
tau_diff_array_ = []
tau_perc_array_ = []
tau_wns_ = []

for (i,j) in zip(tau3, tau2):
    diff = i[1]-j[1]
    perc = diff/i[1] *100
    tau_diff_array_.append(diff)
    tau_perc_array_.append(perc)
    tau_wns_.append(i[0])
    
plt.figure(figsize=(15,10))
plt.scatter(tau_wns_,tau_perc_array_, s=1)
plt.ylim(-10,10)
plt.show()
# Out:
# /Users/micol/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Therefore we will vary tau by 2%

# %%
print(len(delta_atm_t[8]))
# Out:
# 2471

# %%
inc_atm_t = delta_atm_t[8]
dec_atm_t = delta_atm_t[0]

inc_surf_t = delta_surf_t[10]
dec_surf_t = delta_surf_t[0]

inc_down = delta_down[2]
dec_down = delta_down[1]

inc_up = delta_up[2]
dec_up = delta_up[1]

inc_tau = delta_tau[4]
dec_tau = delta_tau[0]


ems_increase_ = []
ems_decrease_ = []

test = [inc_atm_t, dec_atm_t, inc_surf_t, dec_surf_t, inc_down, dec_down, inc_up, dec_up, inc_tau, dec_tau]

for i in test:
    for a in i:
        if a>0:
            ems_increase_.append(a)
            ems_decrease_.append(0)
        else:
            ems_increase_.append(0)
            ems_decrease_.append(a)

ems_increase = np.reshape(ems_increase_, (10, len(inc_atm_t)))
ems_decrease = np.reshape(ems_decrease_, (10, len(inc_atm_t)))

# %%
fig = plt.figure(figsize=(14,10))

pltsize= 2

plt.scatter(wns, inc_atm_t, s=pltsize)
plt.scatter(wns, dec_atm_t, s=pltsize)

plt.scatter(wns, inc_surf_t, s=pltsize)
plt.scatter(wns, dec_surf_t, s=pltsize)

plt.scatter(wns, inc_down, s=pltsize)
plt.scatter(wns, dec_down, s=pltsize)

plt.scatter(wns, inc_up, s=pltsize)
plt.scatter(wns, dec_up, s=pltsize)

plt.scatter(wns, inc_tau, s=pltsize)
plt.scatter(wns, dec_tau, s=pltsize)

# Highlight bands were supposedly weird things happen
plt.axvspan(799, 836, alpha=0.3, color='yellow', zorder=-1)
plt.axvspan(919, 955, alpha=0.3, color='yellow', zorder=-1)
plt.axvspan(1039, 1070, alpha=0.3, color='yellow', zorder=-1)

# Zoom into interesting area
plt.xlim(780,1100)
plt.ylim(-0.1,0.1)

plt.show()

# %%
# Let's work with Numpy arrays!
deviations = [
    np.array(inc_atm_t),
    np.array(dec_atm_t),
    np.array(inc_surf_t),
    np.array(dec_surf_t),
    np.array(inc_down),
    np.array(dec_down),
    np.array(inc_up),
    np.array(dec_up),
    np.array(inc_tau),
    np.array(dec_tau),
]

z = np.zeros(len(deviations[0])) # All deviations should have the same length
sq_dev_pos = sq_dev_neg = z

for dev in deviations:
    sq_dev_pos = np.add(sq_dev_pos, np.square(np.maximum(dev, z)))
    sq_dev_neg = np.add(sq_dev_neg, np.square(np.minimum(dev, z)))

err_pos = np.sqrt(sq_dev_pos) # Summation of quadratic errors from positive deviations
err_neg = np.sqrt(sq_dev_neg) # Summation of quadratic errors from negative deviations

# %%
fig = plt.figure(figsize=(14,10))
pltsize= 2

plt.scatter(wns, emissivity, s=pltsize)
#plt.scatter(wns, emissivity + err_pos, s=pltsize)
#plt.scatter(wns, emissivity - err_neg, s=pltsize)

plt.fill_between(wns[0:619], np.array(emissivity[0:619]) - np.array(err_neg[0:619]), np.array(emissivity[0:619]) + np.array(err_pos[0:619]),
                 color='gray', alpha=0.2)
plt.fill_between(wns[619:], np.array(emissivity[619:]) - np.array(err_neg[619:]), np.array(emissivity[619:]) + np.array(err_pos[619:]),
                 color='gray', alpha=0.2)

# Highlight bands were supposedly weird things happen
"""plt.axvspan(799, 836, alpha=0.3, color='yellow', zorder=-1)
plt.axvspan(919, 955, alpha=0.3, color='yellow', zorder=-1)
plt.axvspan(1039, 1070, alpha=0.3, color='yellow', zorder=-1)"""

# Zoom into interesting area
#plt.xlim(780,1100)
plt.ylim(0, 1.1)
#plt.ylim(-10, 10)

plt.show()
